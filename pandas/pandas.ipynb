# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col= 'Respondent')

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
# To print out all the columns when printing df use the following setting
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
# df.info gives all the information about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col= 'Column')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# to get the counter of each response
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
# to grab a specific rows
df['Hobbyist'].loc[0]
# Out:
# 'Yes'

# %%
# to get the first row in its entirety
df.loc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
# response of multiple rows for a column
df.loc[[0,1,2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
# we can also use slicing, the last value is inclusive in the case of loc
df.loc[0:2, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
# to slice the columns also from one to another
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
# ...

# %%
 df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df.loc['SurveyEase', 'QuestionText']
# Out:
# 'How easy or difficult was this survey to complete?'

# %%
#to sort index in order.To order descending, set ascending attribute to False, inplace = true, if we want to make the changes to the dataframe
schema_df.sort_index(inplace = True)

# %% [markdown]
# ## [Using Conditionals to Filter rows and Columns](https://www.youtube.com/watch?v=Lw2rlcxScZY&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=4)

# %%
schema_df.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
# for salary but not present in the 2020 dataset
# high_salary = (df['ConvertedComp'] > 70000)
#df.loc[high_salary]
#df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]

# %%
#filter by list
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada' ]
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 5         United States
# 6               Germany
# 7                 India
#               ...
# 62834            Canada
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 30849, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
# get language worked with is python
filt = df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# using the filtering, true false values apply a mask to the dataframe and returns the rows that matches the true value
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
df.rename(columns = {'LanguageWorkedWith': 'LanguagesUsed'})
# Out:
#                                                      NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                                 LanguagesUsed  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# ...

# %%
 df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.sort_values(by = 'Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 8631     Afghanistan
# 25001    Afghanistan
# 58171    Afghanistan
# 42668    Afghanistan
# 51509    Afghanistan
# 37951    Afghanistan
# 28374    Afghanistan
# 7616     Afghanistan
# 43966    Afghanistan
# 62698    Afghanistan
# 51532    Afghanistan
# 36574    Afghanistan
# 43946    Afghanistan
# 65381    Afghanistan
# 38672    Afghanistan
# 35753    Afghanistan
# 43808    Afghanistan
# 37159    Afghanistan
# 44555    Afghanistan
# 35687    Afghanistan
# 37605    Afghanistan
# 44556    Afghanistan
# 23798    Afghanistan
# 42188    Afghanistan
# 65456    Afghanistan
# 44697    Afghanistan
# 60507    Afghanistan
# 898      Afghanistan
# 51900    Afghanistan
# 35179    Afghanistan
# 2932     Afghanistan
# 55019    Afghanistan
# 15422    Afghanistan
# 46844    Afghanistan
# 45481    Afghanistan
# 51862    Afghanistan
# 63848    Afghanistan
# 35656    Afghanistan
# 33878    Afghanistan
# 26575    Afghanistan
# 37601    Afghanistan
# 9839     Afghanistan
# ...

# %%
# df[['Country', 'ConvertedComp]].head() # not present in 2020 data
# sort salary by descending
#df.sort_values(by=['Country', 'ConvertedComp'], ascending = [True, False], inplace = True)

# %%
# top 10 
#df['ConvertedComp'].nlargest(10)

# %%
#all rows for the top 10
# df.nlargest(10, 'ConvertedComp')
# FOR ROWS IN THE LOWEST
# df.nsmallest(10, 'ConvertedComp')
