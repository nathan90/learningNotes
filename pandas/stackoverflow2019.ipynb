# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public2019.csv', index_col= 'Respondent')
schema_df = pd.read_csv('data/survey_results_schema2019.csv', index_col= 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
# to get the median salary
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# it goes through the column and looks at numerical data columns that we can get median values for
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# The count value gives the number of non missing rows count
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
# to see in percentages pass in the normalize argument
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
# Grouping data

If we want to see specific results based on some other column, we have to group on that column  
Group by operation includes splitting an object, applying a function, combine the results

# %%
df['Country'].value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Brunei Darussalam            1
# Tonga                        1
# Sao Tome and Principe        1
# North Korea                  1
# Timor-Leste                  1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#           Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# ...

# %%
# same method can be done by filter
filt = df['Country'] =='United States'
df.loc[filt]
# Out:
#   NaN
#
#                                       DatabaseDesireNextYear  \
# Respondent
# 4                                               MySQL;SQLite
# 13                                      Firebase;MySQL;Redis
# 22                          Elasticsearch;MySQL;Oracle;Redis
# 23          Couchbase;DynamoDB;Elasticsearch;Firebase;Oracle
# 26                   Microsoft SQL Server;MySQL;Redis;SQLite
# ...                                                      ...
# 78292                                                 SQLite
# 82717                                                    NaN
# 83397                                                    NaN
# 85642                                                    NaN
# 88282                                                    NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 4                                               Linux;Windows
# 13          Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# ...

# %%
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# this series have multiple indexes
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
# median by country
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
x = (country_grp['ConvertedComp'].median())
type(x)
# Out:
# pandas.core.series.Series

# %%
# import matplotib as plot
import matplotlib.pyplot as plt
x.plot.bar()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
# agg method
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
#gives the sum of how many who have worked in python from india
# Out:
# 3105

# %%
#
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# this doesnt work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-1a132121a376> in <module>
#       1 #
# ----> 2 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# c:\Users\vishw\Desktop\AdvancedStuff\pandas\learnpandas\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
x = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).div(country_grp['LanguageWorkedWith'].agg('count')).multiply(other = 100)
#above solution is wrong since count ignores NaN

# %%
x
# Out:
# Country
# Afghanistan                             20.512821
# Albania                                 27.710843
# Algeria                                 31.746032
# Andorra                                  0.000000
# Angola                                  50.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    32.183908
# Viet Nam                                35.454545
# Yemen                                   17.647059
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
 country_respondants = type(country_grp['LanguageWorkedWith'].agg('count'))
# Out:
# pandas.core.series.Series

# %%
#another method
ctr_knows_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()/len(x)).multiply(other = 100)

# %%
ctr_knows_python
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64
